# %%
using DifferentialEquations, Plots, IJulia

# %%
# Setup the ODE function
function lotka_volterra!(du, u, p, t)
    x, y = u
    α, β, δ, γ = p
    du[1] = dx = α * x - β * x * y
    du[2] = dy = -δ * y + γ * x * y
end
# Out:
# lotka_volterra! (generic function with 1 method)

# %%
# Initial condition
u0 = [1.0, 1.0]

# Simulation interval
tspan = (0.0, 10.0)

# LV equation parameters p = [α, β, δ, γ]
parameters = [1.0, 1.2, 2.5, 1.2]
# Out:
# 4-element Vector{Float64}:
#  1.0
#  1.2
#  2.5
#  1.2

# %%
# Set up the ODE problem with our guessed parameter values
prob = ODEProblem(lotka_volterra!, u0, tspan, parameters)

# Solve the ODE problem with our guessed parameter values
initial_sol = solve(prob, saveat = 0.01)

# View the guessed model solution
plt = plot(initial_sol, label = ["x Prediction" "y Prediction"])

# %%
# Define experimental data
t_data = 0:10
x_data = [1.000 2.773 6.773 0.971 1.886 6.101 1.398 1.335 4.353 3.247 1.034]
y_data = [1.000 0.259 2.015 1.908 0.323 0.629 3.458 0.508 0.314 4.547 0.906]
xy_data = vcat(x_data, y_data)

# Plot the provided data
scatter(t_data, xy_data', label = ["x Data" "y Data"])

# %%
# Set up the ODE problem with our guessed parameter values
prob = ODEProblem(lotka_volterra!, u0, tspan, parameters)

# Solve the ODE problem with our guessed parameter values
initial_sol = solve(prob, saveat = 1)

# View the guessed model solution
plt = plot(initial_sol, label = ["x Prediction" "y Prediction"])
scatter!(plt, t_data, xy_data', label = ["x Data" "y Data"])

# %%
# How do we estimate parameters?

# %%
# Define a loss metric function to be minimized
function loss(newp)
    newprob = remake(prob, p = newp)
    sol = solve(newprob, saveat = 1)
    loss = sum(abs2, sol .- xy_data)
    return loss
end

using Optimization, OptimizationPolyalgorithms
# Define a callback function to monitor optimization progress
function callback(state, l)
    display(l)
    newprob = remake(prob, p = state.u)
    sol = solve(newprob, saveat = 0.1)
    plt = plot(sol, ylim = (0, 6), label = ["Current x Prediction" "Current y Prediction"])
    scatter!(plt, t_data, xy_data', label = ["x Data" "y Data"])
    IJulia.clear_output(true)
    display(plt)
    return false
end

pguess = [1.0, 1.2, 2.5, 1.2]

# Set up the optimization problem with our loss function and initial guess
adtype = AutoForwardDiff()
optf = OptimizationFunction((x, _) -> loss(x), adtype)
optprob = OptimizationProblem(optf, pguess)

# Optimize the ODE parameters for best fit to our data
pfinal = solve(optprob, PolyOpt(),
    callback = callback,
    maxiters = 200)
α, β, γ, δ = round.(pfinal, digits = 1)
# Out:
# UndefVarError: `prob` not defined
#
# Stacktrace:
#  [1] loss(newp::Vector{Float64})
#    @ Main .\In[1]:3
#  [2] (::var"#1#2")(x::Vector{Float64}, ::SciMLBase.NullParameters)
#    @ Main .\In[1]:26
#  [3] (::OptimizationFunction{true, AutoForwardDiff{nothing, Nothing}, var"#1#2", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing})(::Vector{Float64}, ::Vararg{Any})
#    @ SciMLBase C:\Users\davisjad\.julia\packages\SciMLBase\LZvKA\src\scimlfunctions.jl:4251
#  [4] (::OptimizationPolyalgorithms.var"#2#3"{OptimizationProblem{true, OptimizationFunction{true, AutoForwardDiff{nothing, Nothing}, var"#1#2", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, Vector{Float64}, SciMLBase.NullParameters, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, @Kwargs{}}})(x::Vector{Float64})
#    @ OptimizationPolyalgorithms C:\Users\davisjad\.julia\packages\OptimizationPolyalgorithms\5lhpw\src\OptimizationPolyalgorithms.jl:16
#  [5] __solve(::OptimizationProblem{true, OptimizationFunction{true, AutoForwardDiff{nothing, Nothing}, var"#1#2", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, Vector{Float64}, SciMLBase.NullParameters, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, @Kwargs{}}, ::PolyOpt; maxiters::Int64, kwargs::@Kwargs{callback::typeof(callback)})
#    @ OptimizationPolyalgorithms C:\Users\davisjad\.julia\packages\OptimizationPolyalgorithms\5lhpw\src\OptimizationPolyalgorithms.jl:17
#  [6] solve(::OptimizationProblem{true, OptimizationFunction{true, AutoForwardDiff{nothing, Nothing}, var"#1#2", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, Vector{Float64}, SciMLBase.NullParameters, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, @Kwargs{}}, ::PolyOpt; kwargs::@Kwargs{callback::typeof(callback), maxiters::Int64})
#    @ SciMLBase C:\Users\davisjad\.julia\packages\SciMLBase\LZvKA\src\solve.jl:136
#  [7] top-level scope
#    @ In[1]:30
